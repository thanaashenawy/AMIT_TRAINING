# %% [markdown]
# # SF Salaries Exercise

# %% [markdown]
# ** Import pandas as pd.**

# %%
import numpy as np#define numpy library
import pandas as pd#define pands library

# %% [markdown]
# ** Read Salaries.csv as a dataframe called sal.**

# %%
df = pd.read_csv('salaries.csv')#read file csv
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %% [markdown]
# ** Check the head of the DataFrame. **

# %%
df.head()#select 5 of top coluom data
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %% [markdown]
# ** Use the .info() method to find out how many entries there are.**

# %%
df.info()# know basic info of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# **What is the average BasePay ?**

# %%
df.groupby("BasePay").std()
# Out:
#             Id  OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  \
# BasePay
# -166.01    NaN          NaN       NaN       NaN       NaN               NaN
# -121.63    NaN          NaN       NaN       NaN       NaN               NaN
# -109.22    NaN          NaN       NaN       NaN       NaN               NaN
# -106.60    NaN          NaN       NaN       NaN       NaN               NaN
# -101.88    NaN          NaN       NaN       NaN       NaN               NaN
# ...         ..          ...       ...       ...       ...               ...
#  313312.52 NaN          NaN       NaN       NaN       NaN               NaN
#  313686.01 NaN          NaN       NaN       NaN       NaN               NaN
#  315572.01 NaN          NaN       NaN       NaN       NaN               NaN
#  318835.49 NaN          NaN       NaN       NaN       NaN               NaN
#  319275.01 NaN          NaN       NaN       NaN       NaN               NaN
#
#             Year  Notes  Status
# BasePay
# ...

# %% [markdown]
# ** What is the highest amount of OvertimePay in the dataset ? **

# %%
df.groupby("OvertimePay").max()# total max data in overtimepay. i try select the highest amount of overtimepay
# Out:
#                  Id        EmployeeName                              JobTitle  \
# OvertimePay
# -0.01         90715   Claudia M Sanchez             Senior Eligibility Worker
#  0.00        148654          Zuri Jones                           ZOO CURATOR
#  0.02         44426   Leonid Vaynshteyn                   Maintenance Planner
#  0.52         99025     Pamela J Walker                        Deputy Sheriff
#  0.77         33722       JANIEN BISHOP  PUBLIC SERVICE AIDE-SPECIAL PROGRAMS
# ...             ...                 ...                                   ...
#  173547.73   110575  Antonio B Santiago                        Deputy Sheriff
#  192424.49    36164   Frederick Binkley             EMT/Paramedic/Firefighter
#  196689.18    72965       Whitney P Yee                        Deputy Sheriff
#  220909.48    36160      Gary Altenberg          Lieutenant, Fire Suppression
#  245131.88        2        GARY JIMENEZ       CAPTAIN III (POLICE DEPARTMENT)
#
# ...

# %%
#anather solution
df.loc[1,'OvertimePay']#i see that the max value of overtimepay  is 245131.88 so i select his location
# Out:
# 245131.88

# %% [markdown]
# ** What is the job title of  JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll). **

# %%
df[['JobTitle','EmployeeName']]#show all of data for jobtitle
# Out:
#                                               JobTitle       EmployeeName
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     NATHANIEL FORD
# 1                      CAPTAIN III (POLICE DEPARTMENT)       GARY JIMENEZ
# 2                      CAPTAIN III (POLICE DEPARTMENT)     ALBERT PARDINI
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC  CHRISTOPHER CHONG
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)    PATRICK GARDNER
# ...                                                ...                ...
# 148649                                       Custodian      Roy I Tillery
# 148650                                    Not provided       Not provided
# 148651                                    Not provided       Not provided
# 148652                                    Not provided       Not provided
# 148653                      Counselor, Log Cabin Ranch          Joe Lopez
#
# [148654 rows x 2 columns]

# %%
df[['JobTitle','EmployeeName']].iloc[20:148649,:]#search in data on EmployeeName:JOSEPH DRISCOLL
# Out:
#                                   JobTitle      EmployeeName
# 20              ASSISTANT MEDICAL EXAMINER        VENUS AZAR
# 21              ASSISTANT MEDICAL EXAMINER      JUDY MELINEK
# 22               CAPTAIN, FIRE SUPPRESSION     GEORGE GARCIA
# 23      BATTALION CHIEF, (FIRE DEPARTMENT)     VICTOR WYRSCH
# 24               CAPTAIN, FIRE SUPPRESSION   JOSEPH DRISCOLL
# ...                                    ...               ...
# 148644        Stationary Eng, Sewage Plant      Randy D Winn
# 148645           Human Services Technician  Carolyn A Wilson
# 148646                        Not provided      Not provided
# 148647         Communications Dispatcher 2    Joann Anderson
# 148648                           Custodian       Leon Walker
#
# [148629 rows x 2 columns]

# %%
df[['JobTitle','EmployeeName']].iloc[24,:]#the job title of JOSEPH DRISCOLL
# Out:
# JobTitle        CAPTAIN, FIRE SUPPRESSION
# EmployeeName              JOSEPH DRISCOLL
# Name: 24, dtype: object

# %% [markdown]
# ** How much does JOSEPH DRISCOLL make (including benefits)? **

# %%
df[['TotalPayBenefits','EmployeeName']].iloc[24,:]#select the totalpaybenifits
# Out:
# TotalPayBenefits          270324.91
# EmployeeName        JOSEPH DRISCOLL
# Name: 24, dtype: object

# %% [markdown]
# ** What is the name of highest paid person (including benefits)?**

# %%
df.iloc[0,:].transpose()#select the name of highest paid person but with try that make it with transpose
# Out:
# Id                                                               1
# EmployeeName                                        NATHANIEL FORD
# JobTitle            GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# BasePay                                                  167411.18
# OvertimePay                                                    0.0
# OtherPay                                                 400184.25
# Benefits                                                       NaN
# TotalPay                                                 567595.43
# TotalPayBenefits                                         567595.43
# Year                                                          2011
# Notes                                                          NaN
# Agency                                               San Francisco
# Status                                                         NaN
# Name: 0, dtype: object

# %%
#anaother solution
df.loc[0].dropna()#select the name of highest paid person but with try that make it with dropna
# Out:
# Id                                                               1
# EmployeeName                                        NATHANIEL FORD
# JobTitle            GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# BasePay                                                  167411.18
# OvertimePay                                                    0.0
# OtherPay                                                 400184.25
# TotalPay                                                 567595.43
# TotalPayBenefits                                         567595.43
# Year                                                          2011
# Agency                                               San Francisco
# Name: 0, dtype: object

# %% [markdown]
# ** What is the name of lowest paid person (including benefits)? Do you notice something strange about how much he or she is paid?**

# %%
df.loc[148653].transpose()#select the name of lowerst paid person but with try that make it with transpose
#he paied -618.13
# Out:
# Id                                      148654
# EmployeeName                         Joe Lopez
# JobTitle            Counselor, Log Cabin Ranch
# BasePay                                    0.0
# OvertimePay                                0.0
# OtherPay                               -618.13
# Benefits                                   0.0
# TotalPay                               -618.13
# TotalPayBenefits                       -618.13
# Year                                      2014
# Notes                                      NaN
# Agency                           San Francisco
# Status                                     NaN
# Name: 148653, dtype: object

# %% [markdown]
# ** What was the average (mean) BasePay of all employees per year? (2011-2014) ? **

# %%
df.groupby('BasePay').mean()
# Out:
#                   Id  OvertimePay  OtherPay  Benefits   TotalPay  \
# BasePay
# -166.01      72833.0       249.02      0.00      6.56      83.01
# -121.63      72866.0       182.70      0.00      5.44      61.07
# -109.22      72873.0       163.83      0.00      4.32      54.61
# -106.60      72875.0       159.90      0.00      4.66      53.30
# -101.88      72879.0       153.08      0.00      4.55      51.20
# ...              ...          ...       ...       ...        ...
#  313312.52   72932.0         0.00      0.00  82319.51  313312.52
#  313686.01   72927.0         0.00  23236.00  85431.39  336922.01
#  315572.01   72930.0         0.00      0.00  82849.66  315572.01
#  318835.49  110533.0     10712.95  60563.54  89540.23  390111.98
#  319275.01   72926.0         0.00  20007.06  86533.21  339282.07
#
#             TotalPayBenefits    Year  Notes  Status
# BasePay
# -166.01                89.57  2012.0    NaN     NaN
# -121.63                66.51  2012.0    NaN     NaN
# ...

# %%
df[['BasePay','Year']].mean()
# Out:
# BasePay    66325.448841
# Year        2012.522643
# dtype: float64

# %%
df['Year']
# Out:
# 0         2011
# 1         2011
# 2         2011
# 3         2011
# 4         2011
#           ...
# 148649    2014
# 148650    2014
# 148651    2014
# 148652    2014
# 148653    2014
# Name: Year, Length: 148654, dtype: int64

# %% [markdown]
# ** How many unique job titles are there? **

# %%
df['JobTitle'].nunique()#select no of unique job title
# Out:
# 2159

# %% [markdown]
# ** What are the top 5 most common jobs? **

# %%
df['JobTitle'].head()#select the top jobs by head
# Out:
# 0    GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                   CAPTAIN III (POLICE DEPARTMENT)
# 2                   CAPTAIN III (POLICE DEPARTMENT)
# 3              WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# Name: JobTitle, dtype: object

# %% [markdown]
# ** How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?) **

# %%
df['JobTitle'].nunique(196689.18)# no of Job Titles by only one person
# Out:
# 2159

# %% [markdown]
# ** How many people have the word Chief in their job title? (This is pretty tricky) **

# %%
df['JobTitle'('Chief')].nunique()#show  no of pepole with thier name word chief
# Out:
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16540\338345063.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   df['JobTitle'('Chief')].nunique()
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16540\338345063.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   df['JobTitle'('Chief')].nunique()
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16540\338345063.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   df['JobTitle'('Chief')].nunique()
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16540\338345063.py:1: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
#   df['JobTitle'('Chief')].nunique()
# ---------------------------------------------------------------------------
# ...

# %%
# Out:
# 477

# %% [markdown]
# ** Bonus: Is there a correlation between length of the Job Title string and Salary? **

# %%
x=df['Job Title string'].apply(len)#length of job title
y=df['Job Title Salary'].apply(len)#lengrth of salary
(x,y).corr()#if there correlation
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Job Title string'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Out:
#                   title_len  TotalPayBenefits
# title_len          1.000000         -0.036878
# TotalPayBenefits  -0.036878          1.000000

# %% [markdown]
# # Great Job!
